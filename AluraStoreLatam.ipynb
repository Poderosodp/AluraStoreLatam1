# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
#Calcular Ingresos por tienda
def calculo_Ingresos(tienda: pd.DataFrame) -> float:
    return tienda['Precio'].sum()

ingresosTienda = calculo_Ingresos(tienda)
ingresosTienda2 = calculo_Ingresos(tienda2)
ingresosTienda3 = calculo_Ingresos(tienda3)
ingresosTienda4 = calculo_Ingresos(tienda4)

#Imprimir resultados
print(f"Ingresos de la Tienda 1: {ingresosTienda}")
print(f"Ingresos de la Tienda 2: {ingresosTienda2}")
print(f"Ingresos de la Tienda 3: {ingresosTienda3}")
print(f"Ingresos de la Tienda 4: {ingresosTienda4}")

listaTiendaIngresos = [ingresosTienda, ingresosTienda2, ingresosTienda3, ingresosTienda4]
listaTiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

colores_hex = ['#A9A9A9', '#8FBC8F', '#778899', '#BC8F8F']
plt.bar(x= listaTiendas, height=listaTiendaIngresos, color=colores_hex)
plt.title('Ingresos por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ingresos')
plt.show()
# Out:
# Ingresos de la Tienda 1: 1150880400.0
# Ingresos de la Tienda 2: 1116343500.0
# Ingresos de la Tienda 3: 1098019600.0
# Ingresos de la Tienda 4: 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Calcular todas las ventas por categoria
def ventas_X_categoria(tienda_df, nombre_tienda):
    ventas_categoria = tienda_df['Categoría del Producto'].value_counts()

    print(f"\nVentas por categoría en la {nombre_tienda}:\n")
    print(ventas_categoria)

    # Creación del gráfico circular
    colores = ['#4B8BBE', '#306998', '#FFE873', '#FFD43B', '#646464']
    plt.figure(figsize=(8, 8))
    plt.pie(ventas_categoria, labels=ventas_categoria.index, autopct='%1.1f%%', startangle=140, colors=colores)
    plt.title(f'Ventas por categoría en de la {nombre_tienda}')
    plt.axis('equal')
    plt.show()

# Ejecución de cálculo por tienda
ventas_X_categoria(tienda, 'Tienda 1')
ventas_X_categoria(tienda2, 'Tienda 2')
ventas_X_categoria(tienda3, 'Tienda 3')
ventas_X_categoria(tienda4, 'Tienda 4')
# Out:
# Ventas por categoría en la Tienda 1:
#
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Ventas por categoría en la Tienda 2:
#
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Ventas por categoría en la Tienda 3:
#
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular promedio por tienda
def calificacion_promedio(tienda: pd.DataFrame) -> float:
    return round(tienda['Calificación'].mean(), 4)

calificacionTienda = calificacion_promedio(tienda)
calificacionTienda2 = calificacion_promedio(tienda2)
calificacionTienda3 = calificacion_promedio(tienda3)
calificacionTienda4 = calificacion_promedio(tienda4)

print(f'Calificación promedio Tienda 1 = {calificacionTienda}')
print(f'Calificación promedio Tienda 2 = {calificacionTienda2}')
print(f'Calificación promedio Tienda 3 = {calificacionTienda3}')
print(f'Calificación promedio Tienda 4 = {calificacionTienda4}')

listaTiendaCalificacion = [calificacionTienda, calificacionTienda2, calificacionTienda3, calificacionTienda4]
listaTiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
plt.plot(listaTiendas, listaTiendaCalificacion, marker='o')
plt.xlabel('Tienda')
plt.ylabel('Promedio')
plt.title('Calificación promedio por tienda')
plt.grid(True)
plt.show()
# Out:
# Calificación promedio Tienda 1 = 3.9767
# Calificación promedio Tienda 2 = 4.0373
# Calificación promedio Tienda 3 = 4.0483
# Calificación promedio Tienda 4 = 3.9958

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Carcular productos mas y menos vendidos
def product_vendidos_masomenos(tienda_df: pd.DataFrame, nombre_tienda: str):
    ventas_por_producto = tienda_df.groupby('Producto').size().sort_values(ascending=False)

    print(f"\nProductos más vendidos en al {nombre_tienda}:")
    print(ventas_por_producto.head())

    print(f"\nProductos menos vendidos en al {nombre_tienda}:")
    print(ventas_por_producto.tail())

    #Gráfico
    plt.figure(figsize=(12, 6))
    color_mas = '#4B8BBE'
    color_menos = '#A9A9A9'

    # Productos más vendidos
    ventas_por_producto.head().plot(kind='bar', color= color_mas, ax=plt.gca())
    plt.title(f'Top de los 5 productos más vendidos en la {nombre_tienda}')
    plt.xlabel('Productos')
    plt.ylabel('Ventas')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

    # Productos menos vendidos
    plt.figure(figsize=(12, 6))
    ventas_por_producto.tail().plot(kind='bar', color= color_menos, ax=plt.gca())
    plt.title(f'Top de los 5 productos menos vendidos en la {nombre_tienda}')
    plt.xlabel('Productos')
    plt.ylabel('Ventas')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Cálculo por tienda
product_vendidos_masomenos(tienda, 'Tienda 1')
product_vendidos_masomenos(tienda2, 'Tienda 2')
product_vendidos_masomenos(tienda3, 'Tienda 3')
product_vendidos_masomenos(tienda4, 'Tienda 4')
# Out:
# Productos más vendidos en al Tienda 1:
# Producto
# Armario             60
# TV LED UHD 4K       60
# Microondas          60
# Secadora de ropa    58
# Mesa de noche       56
# dtype: int64
#
# Productos menos vendidos en al Tienda 1:
# Producto
# Mochila                      39
# Pandereta                    36
# Olla de presión              35
# Celular ABXY                 33
# Auriculares con micrófono    33
# dtype: int64
# Productos más vendidos en al Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Pandereta                    58
# Guitarra acústica            58
# dtype: int64
#
# Productos menos vendidos en al Tienda 2:
# Producto
# Auriculares        37
# Sillón             35
# Impresora          34
# Mesa de comedor    34
# Juego de mesa      32
# dtype: int64
# Productos más vendidos en al Tienda 3:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calcular costos de envío
def costo_envio(tienda: pd.DataFrame) -> float:
    return round(tienda['Costo de envío'].mean(), 2)

costoEnvioTienda1 = costo_envio(tienda)
costoEnvioTienda2 = costo_envio(tienda2)
costoEnvioTienda3 = costo_envio(tienda3)
costoEnvioTienda4 = costo_envio(tienda4)

print(f'Costo promedio de envío de la Tienda 1 = {costoEnvioTienda1}')
print(f'Costo promedio de envío de la Tienda 2 = {costoEnvioTienda2}')
print(f'Costo promedio de envío de la Tienda 3 = {costoEnvioTienda3}')
print(f'Costo promedio de envío de la Tienda 4 = {costoEnvioTienda4}')

costos_envio = {
    'Tienda 1': costoEnvioTienda1,
    'Tienda 2': costoEnvioTienda2,
    'Tienda 3': costoEnvioTienda3,
    'Tienda 4': costoEnvioTienda4
}

tiendas = list(costos_envio.keys())
promedios = list(costos_envio.values())

plt.figure(figsize=(8, 6))
plt.bar(x = tiendas, height=promedios, color=colores_hex)
plt.title('Costo promedio de envío por tienda')
plt.xlabel('Tienda')
plt.ylabel('Costo de envío')
plt.ylim(0, max(promedios) * 1.2)
for i, v in enumerate(promedios):
    plt.text(i, v + 0.1, str(v), ha='center')
plt.show()
# Out:
# Costo promedio de envío de la Tienda 1 = 26018.61
# Costo promedio de envío de la Tienda 2 = 25216.24
# Costo promedio de envío de la Tienda 3 = 24805.68
# Costo promedio de envío de la Tienda 4 = 23459.46

# %% [markdown]
# # Informe Final
#
# En base, a información y parametro establecidos de medición en cada una de las tiendas; se puede resumir la siguente información:
#
# ### Ingresos totales
# Dentro de todas las tiendas, la tienda 4 genera los menores ingresos totales; por lo que representa una baja rentabilidad en comparación a las demás. Por lo que se recomienda la implementaciónd e estrategias que permitan mejorar sus ingresos.
#
# ###Ventas por categoría
# Según la información suministrada y analizada entre las tiendas, podemos obsevar que no se presenta una gran diferencia entre las categorías vendidas. Por lo que se recomienda revisar otros factores que influyan en una opción de venta.
#
# ###Calificaciones de los clientes
# Aunque sus ingreso son mayores a los reportados por la tienda 4, tiene la calificaicón más baja y es la tienda 1. Lo que podria indicar que sus mejoras deben enfocarse en la atención al cliente y prestación de servicio.
#
# ###Productos más y menos vendidos
# Así como la diferencia entre la comparación de categorías por venta en cada tienda no es tan significativa; así mismo, se reporta entre los productos más y menos entre las mismas. Por lo que no hace parte de un punto para la opción de venta.
#
# ###Costo de envío
# La tienda 1, nos reporta un mayor costo de envío; esto debido a su alto número de ventas por lo que lo hace proporcional.
#
# ###Conclusión:
# Como se puede evidenciar la tienda que menos ingresos reporta y que se postual como la más opcional a la venta, es la tienda 4.
#
# Cabe recordar, que la tienda 4 siendo la recomendada para la venta; debe implementar no solo acciones de mejora si no tambíen cada una de las otras tiendas en cuanto atención al cliente y restructuración en los procesos para ser mucho más rentables.
